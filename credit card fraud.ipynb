# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import seaborn as sns
sns.countplot(x='Class', data=df)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.918649e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.682686e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.761736e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.811118e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552103e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.040130e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.698953e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.893285e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.147640e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.772925e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.289524e-16      1.020713   -4.797473     -0.762494
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.duplicated(keep=False).sum()
# Out:
# 1854

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (283726, 31)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df["Class"].describe()
# Out:
# count    283726.000000
# mean          0.001667
# std           0.040796
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Class, dtype: float64

# %%
plt.title('The proportion of fraudulent vs non-fraudulent transactions')
df['Class'].value_counts().plot(kind='pie', autopct="%.2f%%", labels=['Not Fraud','Fraud'],
                                        startangle = 90, colors = ['#C35617', '#FFDEAD'])
plt.show();
print(df.Class.value_counts())
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
print ("Fraud")
print (df.Time[df.Class == 1].describe())
print ()
print ("Not Fraud")
print (df.Time[df.Class == 0].describe())
# Out:
# Fraud
# count       473.000000
# mean      80450.513742
# std       48636.179973
# min         406.000000
# 25%       41203.000000
# 50%       73408.000000
# 75%      129095.000000
# max      170348.000000
# Name: Time, dtype: float64
#
# Not Fraud
# count    283253.000000
# mean      94835.058093
# std       47475.550607
# min           0.000000
# 25%       54233.000000
# 50%       84711.000000
# 75%      139308.000000
# max      172792.000000
# Name: Time, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(12,4))
bins = 50

ax1.hist(df.Time[df.Class == 1], bins = bins)
ax1.set_title('Fraud')

ax2.hist(df.Time[df.Class == 0], bins = bins)
ax2.set_title('Not Fraud')

plt.xlabel('Time (Sec.)')
plt.ylabel('Number of Transactions')
plt.show();

# %%
f, axes = plt.subplots(ncols=2, figsize=(16,10))
colors = ['#C35617', '#FFDEAD']

sns.boxplot(x="Class", y="Amount", data=df, palette = colors, ax=axes[0], showfliers=True)
axes[0].set_title('Class vs Amount')

sns.boxplot(x="Class", y="Amount", data=df, palette = colors, ax=axes[1], showfliers=False)
axes[1].set_title('Class vs Amount without outliers')

plt.show();

# %%
from matplotlib.gridspec import GridSpec
#Select only the anonymized features.
var = df.columns.values

colval = var[1:29]
len(colval)

plt.figure(figsize=(12,28*4))
gs = GridSpec(28, 1)
for i, cn in enumerate(df[colval]):
    ax = plt.subplot(gs[i])
    sns.histplot(df[cn][df.Class == 1], bins=50)
    sns.histplot(df[cn][df.Class == 0], bins=50)
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(cn))
plt.show();

# %%
sns.set(font_scale=1.15)
plt.figure(figsize=(16, 9))
sns.heatmap(df.corr(), cmap='RdBu_r', vmin=-1, vmax=1);

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
ind_col=[col for col in df.columns if col!='Class']
dep_col='Class'

# %%
X=df[ind_col]
Y=df[dep_col]

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
Y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.5,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
from sklearn.metrics import precision_score,f1_score,recall_score,roc_auc_score

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,ConfusionMatrixDisplay

# %%
def Evaluate(Y_Test, Predictions):
    
   
    Accuracy = accuracy_score(Y_Test, Predictions)
    
    Precision = precision_score(Y_Test, Predictions,zero_division=0)
    
    Recall = recall_score(Y_Test, Predictions,zero_division=0)
    
    F1 = f1_score(Y_Test, Predictions,zero_division=0)
    
    AUC=roc_auc_score(Y_Test, Predictions)
    
    Metric = {'Accuracy Score' : Accuracy, 
              
              'Precision Score' : Precision,
              
              'Recall Score' : Recall,
              
              'F1 Score' : F1,
              
              'AUC' : AUC
             }
    
    print(f'Accuracy Score : {Accuracy * 100:.2f}%')
    
    print(f'Precision Score : {Precision * 100:.2f}%')
    
    print(f'Recall Score : {Recall * 100:.2f}%')
    
    print(f'F1 Score : {F1 * 100:.2f}%')
    
    print(f'AUC: {AUC*100:.2f}%')
    
    
    return Metric

# %% [markdown]
# # Model Training on Imbalanced Data

# %%
from sklearn.linear_model import LogisticRegression
def LR(X_train,X_test,y_train,y_test):
    LR_model = LogisticRegression(random_state = 0)
    LR_model.fit(X_train, y_train)
    y_train_pred = LR_model.predict(X_train)
    y_test_pred = LR_model.predict(X_test)
    
    print(f"Classification Report :- \n {classification_report(y_test, y_test_pred)}")
    cm=confusion_matrix(y_test,y_test_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=LR_model.classes_)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,y_test_pred)
    return metric

# %%
LR_metric=LR(X_train,X_test,y_train,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.85      0.54      0.66       232
#
#     accuracy                           1.00    141863
#    macro avg       0.92      0.77      0.83    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.91%
# Precision Score : 85.03%
# Recall Score : 53.88%
# F1 Score : 65.96%
# AUC: 76.93%

# %%
from sklearn.tree import DecisionTreeClassifier
def DT(X_train,X_test,y_train,y_test):
    dt=DecisionTreeClassifier(criterion='entropy')
    dt.fit(X_train,y_train)
    Y_train_pred_dt = dt.predict(X_train)
    Y_pred_dt=dt.predict(X_test)
    print(f"Classification Report :- \n {classification_report(y_test, Y_pred_dt)}")
    cm=confusion_matrix(y_test,Y_pred_dt)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=dt.classes_)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,Y_pred_dt)
    return metric

# %%
dt_metric=DT(X_train,X_test,y_train,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.78      0.68      0.73       232
#
#     accuracy                           1.00    141863
#    macro avg       0.89      0.84      0.86    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.92%
# Precision Score : 78.11%
# Recall Score : 67.67%
# F1 Score : 72.52%
# AUC: 83.82%

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

def KNN(X_train,X_test,y_train,y_test):
    Knn=KNeighborsClassifier(n_neighbors=5)
    Knn.fit(X_train,y_train)
    Y_pred_knn=Knn.predict(X_test)
    
    print(f"Classification Report :- \n {classification_report(y_test, Y_pred_knn)}")
    cm=confusion_matrix(y_test,Y_pred_knn)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=Knn.classes_)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,Y_pred_knn)
    return metric

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 141863
# 141863

# %%
KNN_metric=KNN(X_train,X_test,y_train,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.93      0.73      0.82       232
#
#     accuracy                           1.00    141863
#    macro avg       0.97      0.87      0.91    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.95%
# Precision Score : 93.41%
# Recall Score : 73.28%
# F1 Score : 82.13%
# AUC: 86.63%

# %%
from sklearn.ensemble import RandomForestClassifier

def RF(X_train,X_test,y_train,y_test):
    rf=RandomForestClassifier(max_depth=3,n_estimators=75,n_jobs=5)
    rf.fit(X_train,y_train)
    Y_pred_rf=rf.predict(X_test)
    print(f"Classification Report :- \n {classification_report(y_test, Y_pred_rf)}")
    cm=confusion_matrix(y_test,Y_pred_rf)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf.classes_)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,Y_pred_rf)
    return metric

# %%
RF_metric=RF(X_train,X_test,y_train,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.87      0.58      0.70       232
#
#     accuracy                           1.00    141863
#    macro avg       0.94      0.79      0.85    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.92%
# Precision Score : 87.10%
# Recall Score : 58.19%
# F1 Score : 69.77%
# AUC: 79.09%

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20,random_state=0)

# %%
from sklearn.svm import SVC

def SVM(X_train, X_test, y_train, y_test):
# Building a Support Vector Machine on train data
    svc_model = SVC(C= 0.5, kernel='sigmoid', gamma= 'scale',coef0=0.3,degree=2)
    svc_model.fit(X_train, y_train)
    prediction = svc_model .predict(X_test)
    print(f"Classification Report :- \n {classification_report(y_test, prediction)}")
    cm=confusion_matrix(y_test,prediction)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=svc_model.classes_)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,prediction)
    return metric

# %%
SVC_metric=SVM(X_train, X_test, y_train, y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.47      0.41      0.44       232
#
#     accuracy                           1.00    141863
#    macro avg       0.73      0.71      0.72    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.83%
# Precision Score : 46.60%
# Recall Score : 41.38%
# F1 Score : 43.84%
# AUC: 70.65%

# %%
from skelm import ELMClassifier

def ELM(X_train,X_test,y_train,y_test):
    
    elm=ELMClassifier()
    elm.fit(X_train,y_train)
    elm_pred=elm.predict(X_test)
    print(f"Classification Report :- \n {classification_report(y_test, elm_pred)}")
    cm=confusion_matrix(y_test,elm_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,elm_pred)
    return metric
# Out:
# C:\Users\SIVASAI\anaconda3\lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\Users\SIVASAI\anaconda3\lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\Users\SIVASAI\anaconda3\lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %%
ELM_metric=ELM(X_train,X_test,y_train,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.87      0.75      0.81       232
#
#     accuracy                           1.00    141863
#    macro avg       0.93      0.88      0.90    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.94%
# Precision Score : 86.63%
# Recall Score : 75.43%
# F1 Score : 80.65%
# AUC: 87.71%

# %%
import xgboost as xg
def XGB(X_train,X_test,y_train,y_test):
    xgb=xg.XGBClassifier()
    xgb.fit(X_train,y_train)
    xgb_pred=xgb.predict(X_test)
    print(f"Classification Report :- \n {classification_report(y_test, xgb_pred)}")
    cm=confusion_matrix(y_test,xgb_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,xgb_pred)
    return metric

# %%
XGB_metric=XGB(X_train,X_test,y_train,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.96      0.74      0.83       232
#
#     accuracy                           1.00    141863
#    macro avg       0.98      0.87      0.92    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.95%
# Precision Score : 95.56%
# Recall Score : 74.14%
# F1 Score : 83.50%
# AUC: 87.07%

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()

# %%
X_train.shape
# Out:
# (141863, 30)

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# check the shape again
X_train.shape, X_test.shape
# Out:
# ((141863, 30, 1), (141863, 30, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Conv1D,BatchNormalization,Dropout,Activation

# %%
# plot
def plot_learningcurve(history,epochs):
  epoch=range(1,epochs+1)
  # accuracy
  plt.plot(epoch, history.history['accuracy'])
  plt.plot(epoch, history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.xlabel('epoch')
  plt.ylabel('accuracy')
  plt.legend(['train','val'], loc='upper left')
  plt.show()

  # loss
  plt.plot(epoch, history.history['loss'])
  plt.plot(epoch, history.history['val_loss'])
  plt.title('Model loss')
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['train','val'], loc='upper left')
  plt.show()

# %%
# import model
def CNN_11_Layers(X_train,X_test,y_train,y_test):
    model=Sequential()
    # layers
    model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=X_train[0].shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    # build ANN
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='relu'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    history=model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test))
    yp = model.predict(X_test)
    y_pred = []
    for element in yp:
        if element > 0.5:
            y_pred.append(1)
        else:
            y_pred.append(0)

    cm=confusion_matrix(y_test,y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,y_pred)
    plot_learningcurve(history,10)
    return metric

# %%
CNN_11_metric=CNN_11_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 29, 32)            96
#
#  batch_normalization (BatchN  (None, 29, 32)           128
#  ormalization)
#
#  dropout (Dropout)           (None, 29, 32)            0
#
#  conv1d_1 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_1 (Batc  (None, 28, 64)           256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 64)            0
#
#  flatten (Flatten)           (None, 1792)              0
#
#  dense (Dense)               (None, 64)                114752
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/10
# ...

# %%
Metrics=pd.DataFrame({'KNN':KNN_metric,
                       'RF':RF_metric,
                       'LR':LR_metric,
                      'DT':dt_metric,
                      'SVM':SVC_metric,
                      'ELM':ELM_metric,
                      'XGB':XGB_metric,
                      'CNN':CNN_11_metric
                     })

Metrics.head(6)
# Out:
#                       KNN        RF        LR        DT       SVM       ELM  \
# Accuracy Score   0.999478  0.999175  0.999091  0.999161  0.998266  0.999408
# Precision Score  0.934066  0.870968  0.850340  0.781095  0.466019  0.866337
# Recall Score     0.732759  0.581897  0.538793  0.676724  0.413793  0.754310
# F1 Score         0.821256  0.697674  0.659631  0.725173  0.438356  0.806452
# AUC              0.866337  0.790878  0.769319  0.838207  0.706508  0.877060
#
#                       XGB       CNN
# Accuracy Score   0.999521  0.998372
# Precision Score  0.955556  1.000000
# Recall Score     0.741379  0.004310
# F1 Score         0.834951  0.008584
# AUC              0.870661  0.502155

# %%
Metrics.transpose().plot.bar(xlabel='classifiers',ylabel='Performance',
                             y=['Accuracy Score','Recall Score','AUC'],
                             figsize=(15,5),
                             title='Comparison of Accuracy,Recall,AUC for all classifiers on imbalanced Data')
# Out:
# <AxesSubplot:title={'center':'Comparison of Accuracy,Recall,AUC for all classifiers on imbalanced Data'}, xlabel='classifiers', ylabel='Performance'>

# %%
def CNN_14_Layers(X_train,X_test,y_train,y_test):
    
    # import model
    model=Sequential()
    # layers
    model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=X_train[0].shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # build ANN
    model.add(Flatten())
    model.add(Activation('relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(25, activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    history=model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test))
    yp = model.predict(X_test)
    y_pred = []
    for element in yp:
        if element > 0.5:
            y_pred.append(1)
        else:
            y_pred.append(0)

    cm=confusion_matrix(y_test,y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,y_pred)
    plot_learningcurve(history,10)
    return metric

# %%
CNN_14_metric=CNN_14_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_2 (Conv1D)           (None, 29, 32)            96
#
#  batch_normalization_2 (Batc  (None, 29, 32)           128
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 29, 32)            0
#
#  conv1d_3 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_3 (Batc  (None, 28, 64)           256
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 28, 64)            0
#
#  flatten_1 (Flatten)         (None, 1792)              0
#
#  activation (Activation)     (None, 1792)              0
#
#  dense_2 (Dense)             (None, 64)                114752
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 100)               6500
#
#  dense_4 (Dense)             (None, 50)                5050
#
# ...

# %%
def CNN_17_Layers(X_train,X_test,y_train,y_test):
    # import model
    model=Sequential()
    # layers
    model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=X_train[0].shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    # build ANN
    model.add(Flatten())
    model.add(Activation('relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(100, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(25, activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    history=model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test))
    yp = model.predict(X_test)
    y_pred = []
    for element in yp:
        if element > 0.5:
            y_pred.append(1)
        else:
            y_pred.append(0)

    cm=confusion_matrix(y_test,y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,y_pred)
    plot_learningcurve(history,10)
    return metric

# %%
model=CNN_17_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_4 (Conv1D)           (None, 29, 32)            96
#
#  batch_normalization_4 (Batc  (None, 29, 32)           128
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 29, 32)            0
#
#  conv1d_5 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_5 (Batc  (None, 28, 64)           256
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 28, 64)            0
#
#  conv1d_6 (Conv1D)           (None, 27, 64)            8256
#
#  batch_normalization_6 (Batc  (None, 27, 64)           256
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 27, 64)            0
#
#  flatten_2 (Flatten)         (None, 1728)              0
#
#  activation_1 (Activation)   (None, 1728)              0
#
#  dense_7 (Dense)             (None, 64)                110656
#
# ...

# %%
def CNN_20_Layers(X_train,X_test,y_train,y_test):
    model=Sequential()
    # layers
    model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=X_train[0].shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    # build ANN
    model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Activation('relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(100, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(25, activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    history=model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test))
    yp = model.predict(X_test)
    y_pred = []
    for element in yp:
        if element > 0.5:
            y_pred.append(1)
        else:
            y_pred.append(0)

    cm=confusion_matrix(y_test,y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.grid(False)
    plt.show()
    metric=Evaluate(y_test,y_pred)
    plot_learningcurve(history,10)
    return metric

# %%
model=CNN_20_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_7 (Conv1D)           (None, 29, 32)            96
#
#  batch_normalization_7 (Batc  (None, 29, 32)           128
#  hNormalization)
#
#  dropout_10 (Dropout)        (None, 29, 32)            0
#
#  conv1d_8 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_8 (Batc  (None, 28, 64)           256
#  hNormalization)
#
#  dropout_11 (Dropout)        (None, 28, 64)            0
#
#  conv1d_9 (Conv1D)           (None, 27, 64)            8256
#
#  batch_normalization_9 (Batc  (None, 27, 64)           256
#  hNormalization)
#
#  dropout_12 (Dropout)        (None, 27, 64)            0
#
#  conv1d_10 (Conv1D)          (None, 26, 64)            8256
#
#  batch_normalization_10 (Bat  (None, 26, 64)           256
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 26, 64)            0
#
# ...

# %% [markdown]
# # Model Building on Balanced Data with Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4,random_state=42)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
rus = RandomUnderSampler()
# resampling X, y
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

# %%
print('Before sampling class distribution: ', Counter(y_train))
# New class distribution
print('New class distribution: ', Counter(y_train_rus))
# Out:
# Before sampling class distribution:  Counter({0: 169935, 1: 300})
# New class distribution:  Counter({0: 300, 1: 300})

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
LR_rus_metric=LR(X_train_rus,X_test,y_train_rus,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98    113318
#            1       0.04      0.91      0.08       173
#
#     accuracy                           0.97    113491
#    macro avg       0.52      0.94      0.53    113491
# weighted avg       1.00      0.97      0.98    113491
# Accuracy Score : 96.69%
# Precision Score : 4.03%
# Recall Score : 90.75%
# F1 Score : 7.72%
# AUC: 93.73%

# %%
DT_rus_metric=DT(X_train_rus,X_test,y_train_rus,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94    113318
#            1       0.01      0.88      0.02       173
#
#     accuracy                           0.89    113491
#    macro avg       0.51      0.89      0.48    113491
# weighted avg       1.00      0.89      0.94    113491
# Accuracy Score : 88.97%
# Precision Score : 1.21%
# Recall Score : 88.44%
# F1 Score : 2.39%
# AUC: 88.70%

# %%
Knn_rus_metric=KNN(X_train_rus,X_test,y_train_rus,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    113318
#            1       0.07      0.87      0.14       173
#
#     accuracy                           0.98    113491
#    macro avg       0.54      0.93      0.56    113491
# weighted avg       1.00      0.98      0.99    113491
# Accuracy Score : 98.33%
# Precision Score : 7.47%
# Recall Score : 87.28%
# F1 Score : 13.76%
# AUC: 92.82%

# %%
RF_rus_metric=RF(X_train_rus,X_test,y_train_rus,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    113318
#            1       0.13      0.86      0.22       173
#
#     accuracy                           0.99    113491
#    macro avg       0.56      0.92      0.61    113491
# weighted avg       1.00      0.99      0.99    113491
# Accuracy Score : 99.08%
# Precision Score : 12.67%
# Recall Score : 85.55%
# F1 Score : 22.07%
# AUC: 92.32%

# %%
SVM_rus_metric=SVM(X_train_rus,X_test,y_train_rus,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113318
#            1       0.56      0.79      0.66       173
#
#     accuracy                           1.00    113491
#    macro avg       0.78      0.89      0.83    113491
# weighted avg       1.00      1.00      1.00    113491
# Accuracy Score : 99.87%
# Precision Score : 56.43%
# Recall Score : 78.61%
# F1 Score : 65.70%
# AUC: 89.26%

# %%
ELM_rus_metric=ELM(X_train_rus,X_test,y_train_rus,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98    113318
#            1       0.04      0.88      0.08       173
#
#     accuracy                           0.97    113491
#    macro avg       0.52      0.92      0.53    113491
# weighted avg       1.00      0.97      0.98    113491
# Accuracy Score : 96.84%
# Precision Score : 4.09%
# Recall Score : 87.86%
# F1 Score : 7.82%
# AUC: 92.36%

# %%
XGB_rus_metric=XGB(X_train_rus,X_test,y_train_rus,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99    113318
#            1       0.05      0.90      0.10       173
#
#     accuracy                           0.97    113491
#    macro avg       0.53      0.94      0.54    113491
# weighted avg       1.00      0.97      0.99    113491
# Accuracy Score : 97.44%
# Precision Score : 5.13%
# Recall Score : 90.17%
# F1 Score : 9.70%
# AUC: 93.81%

# %%
y_train=y_train_rus.to_numpy()
y_test=y_test.to_numpy()

# %%
X_train=X_train_rus

# %%
X_train.shape
# Out:
# (600, 30)

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# check the shape again
X_train.shape, X_test.shape
# Out:
# ((600, 30, 1), (113491, 30, 1))

# %%
CNN_11_metric=CNN_11_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_11 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_11 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 29, 32)            0
#
#  conv1d_12 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_12 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 28, 64)            0
#
#  flatten_4 (Flatten)         (None, 1792)              0
#
#  dense_17 (Dense)            (None, 64)                114752
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_18 (Dense)            (None, 1)                 65
#
# ...
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/10
# ...

# %%
Metrics_rus=pd.DataFrame({'KNN':Knn_rus_metric,
                       'RF':RF_rus_metric,
                       'LR':LR_rus_metric,
                      'DT':DT_rus_metric,
                      'SVM':SVM_rus_metric,
                      'ELM':ELM_rus_metric,
                      'XGB':XGB_rus_metric,
                      'CNN':CNN_11_metric
                     })

Metrics_rus.head(6)
# Out:
#                       KNN        RF        LR        DT       SVM       ELM  \
# Accuracy Score   0.983320  0.990792  0.966949  0.889665  0.998749  0.968420
# Precision Score  0.074679  0.126712  0.040339  0.012090  0.564315  0.040915
# Recall Score     0.872832  0.855491  0.907514  0.884393  0.786127  0.878613
# F1 Score         0.137585  0.220731  0.077245  0.023854  0.657005  0.078189
# AUC              0.928161  0.923245  0.937277  0.887033  0.892600  0.923585
#
#                       XGB       CNN
# Accuracy Score   0.974412  0.990546
# Precision Score  0.051265  0.121849
# Recall Score     0.901734  0.838150
# F1 Score         0.097015  0.212766
# AUC              0.938129  0.914464

# %%
Metrics.transpose().plot.bar(xlabel='classifiers',ylabel='Performance',
                             y=['Accuracy Score','Recall Score','AUC'],
                             figsize=(15,5),
                             title='Comparison of Accuracy,Recall,AUC for all classifiers on balanced Data using undersampling')
# Out:
# <AxesSubplot:title={'center':'Comparison of Accuracy,Recall,AUC for all classifiers on balanced Data using undersampling'}, xlabel='classifiers', ylabel='Performance'>

# %%
model=CNN_14_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_13 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_13 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 29, 32)            0
#
#  conv1d_14 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_14 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 28, 64)            0
#
#  flatten_5 (Flatten)         (None, 1792)              0
#
#  activation_3 (Activation)   (None, 1792)              0
#
#  dense_19 (Dense)            (None, 64)                114752
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_20 (Dense)            (None, 100)               6500
#
#  dense_21 (Dense)            (None, 50)                5050
#
# ...

# %%
model=CNN_17_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_15 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_15 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 29, 32)            0
#
#  conv1d_16 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_16 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 28, 64)            0
#
#  conv1d_17 (Conv1D)          (None, 27, 64)            8256
#
#  batch_normalization_17 (Bat  (None, 27, 64)           256
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 27, 64)            0
#
#  flatten_6 (Flatten)         (None, 1728)              0
#
#  activation_4 (Activation)   (None, 1728)              0
#
#  dense_24 (Dense)            (None, 64)                110656
#
# ...

# %%
model=CNN_20_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_18 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_18 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_25 (Dropout)        (None, 29, 32)            0
#
#  conv1d_19 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_19 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_26 (Dropout)        (None, 28, 64)            0
#
#  conv1d_20 (Conv1D)          (None, 27, 64)            8256
#
#  batch_normalization_20 (Bat  (None, 27, 64)           256
#  chNormalization)
#
#  dropout_27 (Dropout)        (None, 27, 64)            0
#
#  conv1d_21 (Conv1D)          (None, 26, 64)            8256
#
#  batch_normalization_21 (Bat  (None, 26, 64)           256
#  chNormalization)
#
#  dropout_28 (Dropout)        (None, 26, 64)            0
#
# ...

# %% [markdown]
# # MODEL BUILDING ON BALANCED DATA WITH OVERSAMPLING

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.5,random_state=42)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
ros = RandomOverSampler()
# resampling X, y
X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)

# %%
print('Before sampling class distribution:', Counter(y_train))
# new class distribution
print('New class distribution:', Counter(y_train_ros))
# Out:
# Before sampling class distribution: Counter({0: 141622, 1: 241})
# New class distribution: Counter({0: 141622, 1: 141622})

# %%
LR_ros_metric=LR(X_train_ros,X_test,y_train_ros,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    141631
#            1       0.08      0.86      0.14       232
#
#     accuracy                           0.98    141863
#    macro avg       0.54      0.92      0.57    141863
# weighted avg       1.00      0.98      0.99    141863
# Accuracy Score : 98.33%
# Precision Score : 7.89%
# Recall Score : 86.21%
# F1 Score : 14.46%
# AUC: 92.28%

# %%
DT_ros_metric=DT(X_train_ros,X_test,y_train_ros,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.75      0.67      0.70       232
#
#     accuracy                           1.00    141863
#    macro avg       0.87      0.83      0.85    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.91%
# Precision Score : 74.52%
# Recall Score : 66.81%
# F1 Score : 70.45%
# AUC: 83.39%

# %%
Knn_ros_metric=KNN(X_train_ros,X_test,y_train_ros,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.67      0.78      0.72       232
#
#     accuracy                           1.00    141863
#    macro avg       0.84      0.89      0.86    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.90%
# Precision Score : 67.16%
# Recall Score : 78.45%
# F1 Score : 72.37%
# AUC: 89.19%

# %%
RF_ros_metric=RF(X_train_ros,X_test,y_train_ros,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.32      0.81      0.46       232
#
#     accuracy                           1.00    141863
#    macro avg       0.66      0.91      0.73    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.68%
# Precision Score : 31.82%
# Recall Score : 81.47%
# F1 Score : 45.76%
# AUC: 90.59%

# %%
SVM_ros_metric=SVM(X_train_ros,X_test,y_train_ros,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95    141631
#            1       0.01      0.84      0.03       232
#
#     accuracy                           0.90    141863
#    macro avg       0.51      0.87      0.49    141863
# weighted avg       1.00      0.90      0.95    141863
# Accuracy Score : 89.94%
# Precision Score : 1.35%
# Recall Score : 84.05%
# F1 Score : 2.66%
# AUC: 87.00%

# %%
ELM_ros_metric=ELM(X_train_ros,X_test,y_train_ros,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    141631
#            1       0.12      0.83      0.20       232
#
#     accuracy                           0.99    141863
#    macro avg       0.56      0.91      0.60    141863
# weighted avg       1.00      0.99      0.99    141863
# Accuracy Score : 98.94%
# Precision Score : 11.61%
# Recall Score : 83.19%
# F1 Score : 20.38%
# AUC: 91.08%

# %%
XGB_ros_metric=XGB(X_train_ros,X_test,y_train_ros,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    141631
#            1       0.92      0.77      0.84       232
#
#     accuracy                           1.00    141863
#    macro avg       0.96      0.89      0.92    141863
# weighted avg       1.00      1.00      1.00    141863
# Accuracy Score : 99.95%
# Precision Score : 91.79%
# Recall Score : 77.16%
# F1 Score : 83.84%
# AUC: 88.57%

# %%
y_train=y_train_ros.to_numpy()
y_test=y_test.to_numpy()

# %%
X_train=X_train_ros

# %%
X_train.shape
# Out:
# (283244, 30)

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# check the shape again
X_train.shape, X_test.shape
# Out:
# ((283244, 30, 1), (141863, 30, 1))

# %%
CNN_11_ros_metric=CNN_11_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_22 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_22 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_30 (Dropout)        (None, 29, 32)            0
#
#  conv1d_23 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_23 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_31 (Dropout)        (None, 28, 64)            0
#
#  flatten_8 (Flatten)         (None, 1792)              0
#
#  dense_34 (Dense)            (None, 64)                114752
#
#  dropout_32 (Dropout)        (None, 64)                0
#
#  dense_35 (Dense)            (None, 1)                 65
#
# ...
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/10
# ...

# %%
Metrics_ros=pd.DataFrame({'KNN':Knn_ros_metric,
                       'RF':RF_ros_metric,
                       'LR':LR_ros_metric,
                      'DT':DT_ros_metric,
                      'SVM':SVM_ros_metric,
                      'ELM':ELM_ros_metric,
                      'XGB':XGB_ros_metric,
                      'CNN':CNN_11_ros_metric
                     })

Metrics_ros.head(6)
# Out:
#                       KNN        RF        LR        DT       SVM       ELM  \
# Accuracy Score   0.999020  0.996842  0.983322  0.999084  0.899410  0.989370
# Precision Score  0.671587  0.318182  0.078927  0.745192  0.013515  0.116125
# Recall Score     0.784483  0.814655  0.862069  0.668103  0.840517  0.831897
# F1 Score         0.723658  0.457627  0.144613  0.704545  0.026603  0.203801
# AUC              0.891927  0.905898  0.922795  0.833865  0.870012  0.910762
#
#                       XGB       CNN
# Accuracy Score   0.999514  0.985077
# Precision Score  0.917949  0.086804
# Recall Score     0.771552  0.853448
# F1 Score         0.838407  0.157581
# AUC              0.885719  0.919371

# %%
Metrics_ros.transpose().plot.bar(xlabel='classifiers',ylabel='Performance',
                             y=['Accuracy Score','Recall Score','AUC'],
                             figsize=(15,5),
                             title='Comparison of Accuracy,Recall,AUC for all classifiers on balanced Data using oversampling')
# Out:
# <AxesSubplot:title={'center':'Comparison of Accuracy,Recall,AUC for all classifiers on balanced Data using oversampling'}, xlabel='classifiers', ylabel='Performance'>

# %%
CNN_14_ros_metric=CNN_14_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_24 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_24 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_33 (Dropout)        (None, 29, 32)            0
#
#  conv1d_25 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_25 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_34 (Dropout)        (None, 28, 64)            0
#
#  flatten_9 (Flatten)         (None, 1792)              0
#
#  activation_6 (Activation)   (None, 1792)              0
#
#  dense_36 (Dense)            (None, 64)                114752
#
#  dropout_35 (Dropout)        (None, 64)                0
#
#  dense_37 (Dense)            (None, 100)               6500
#
#  dense_38 (Dense)            (None, 50)                5050
#
# ...

# %%
CNN_17_ros_metric=CNN_17_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_26 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_26 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 29, 32)            0
#
#  conv1d_27 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_27 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_37 (Dropout)        (None, 28, 64)            0
#
#  conv1d_28 (Conv1D)          (None, 27, 64)            8256
#
#  batch_normalization_28 (Bat  (None, 27, 64)           256
#  chNormalization)
#
#  dropout_38 (Dropout)        (None, 27, 64)            0
#
#  flatten_10 (Flatten)        (None, 1728)              0
#
#  activation_7 (Activation)   (None, 1728)              0
#
#  dense_41 (Dense)            (None, 64)                110656
#
# ...

# %%
CNN_20_ros_metric=CNN_20_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_29 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_29 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_40 (Dropout)        (None, 29, 32)            0
#
#  conv1d_30 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_30 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_41 (Dropout)        (None, 28, 64)            0
#
#  conv1d_31 (Conv1D)          (None, 27, 64)            8256
#
#  batch_normalization_31 (Bat  (None, 27, 64)           256
#  chNormalization)
#
#  dropout_42 (Dropout)        (None, 27, 64)            0
#
#  conv1d_32 (Conv1D)          (None, 26, 64)            8256
#
#  batch_normalization_32 (Bat  (None, 26, 64)           256
#  chNormalization)
#
#  dropout_43 (Dropout)        (None, 26, 64)            0
#
# ...

# %% [markdown]
# # MODEL BUILDING ON BALANCED DATA WITH SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4,random_state=42)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
sm = SMOTE(random_state=27)
# Fitting SMOTE to the train set
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)

# %%
print('Before SMOTE oversampling X_train shape=', X_train.shape)
print('After SMOTE oversampling X_train shape=', X_train_smote.shape)
# Out:
# Before SMOTE oversampling X_train shape= (170235, 30)
# After SMOTE oversampling X_train shape= (339870, 30)

# %%
LR_smote_metric=LR(X_train_smote,X_test,y_train_smote,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99    113318
#            1       0.05      0.92      0.09       173
#
#     accuracy                           0.97    113491
#    macro avg       0.52      0.95      0.54    113491
# weighted avg       1.00      0.97      0.99    113491
# Accuracy Score : 97.32%
# Precision Score : 4.99%
# Recall Score : 91.91%
# F1 Score : 9.46%
# AUC: 94.62%

# %%
DT_smote_metric=DT(X_train_smote,X_test,y_train_smote,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113318
#            1       0.39      0.79      0.52       173
#
#     accuracy                           1.00    113491
#    macro avg       0.70      0.89      0.76    113491
# weighted avg       1.00      1.00      1.00    113491
# Accuracy Score : 99.78%
# Precision Score : 39.08%
# Recall Score : 78.61%
# F1 Score : 52.21%
# AUC: 89.21%

# %%
Knn_smote_metric=KNN(X_train_smote,X_test,y_train_smote,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113318
#            1       0.44      0.84      0.58       173
#
#     accuracy                           1.00    113491
#    macro avg       0.72      0.92      0.79    113491
# weighted avg       1.00      1.00      1.00    113491
# Accuracy Score : 99.81%
# Precision Score : 44.34%
# Recall Score : 83.82%
# F1 Score : 58.00%
# AUC: 91.83%

# %%
RF_smote_metric=RF(X_train_smote,X_test,y_train_smote,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113318
#            1       0.31      0.86      0.46       173
#
#     accuracy                           1.00    113491
#    macro avg       0.66      0.93      0.73    113491
# weighted avg       1.00      1.00      1.00    113491
# Accuracy Score : 99.69%
# Precision Score : 31.09%
# Recall Score : 85.55%
# F1 Score : 45.61%
# AUC: 92.63%

# %%
SVM_smote_metric=SVM(X_train_smote,X_test,y_train_smote,y_test)

# %%
ELM_smote_metric=ELM(X_train_smote,X_test,y_train_smote,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    113318
#            1       0.09      0.87      0.16       173
#
#     accuracy                           0.99    113491
#    macro avg       0.54      0.93      0.58    113491
# weighted avg       1.00      0.99      0.99    113491
# Accuracy Score : 98.60%
# Precision Score : 8.77%
# Recall Score : 87.28%
# F1 Score : 15.95%
# AUC: 92.95%

# %%
XGB_smote_metric=XGB(X_train_smote,X_test,y_train_smote,y_test)
# Out:
# Classification Report :-
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    113318
#            1       0.77      0.81      0.79       173
#
#     accuracy                           1.00    113491
#    macro avg       0.89      0.90      0.90    113491
# weighted avg       1.00      1.00      1.00    113491
# Accuracy Score : 99.93%
# Precision Score : 77.35%
# Recall Score : 80.92%
# F1 Score : 79.10%
# AUC: 90.44%

# %%
y_train=y_train_smote.to_numpy()
y_test=y_test.to_numpy()

# %%
X_train=X_train_smote

# %%
X_train.shape
# Out:
# (339870, 30)

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# check the shape again
X_train.shape, X_test.shape
# Out:
# ((339870, 30, 1), (113491, 30, 1))

# %%
CNN_11_smote_metric=CNN_11_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_33 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_33 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_45 (Dropout)        (None, 29, 32)            0
#
#  conv1d_34 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_34 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_46 (Dropout)        (None, 28, 64)            0
#
#  flatten_12 (Flatten)        (None, 1792)              0
#
#  dense_51 (Dense)            (None, 64)                114752
#
#  dropout_47 (Dropout)        (None, 64)                0
#
#  dense_52 (Dense)            (None, 1)                 65
#
# ...
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/10
# ...

# %%
Metrics_smote=pd.DataFrame({'KNN':Knn_smote_metric,
                       'RF':RF_smote_metric,
                       'LR':LR_smote_metric,
                      'DT':DT_smote_metric,
                      'ELM':ELM_smote_metric,
                      'XGB':XGB_smote_metric,
                      'CNN':CNN_11_smote_metric
                     })

Metrics_smote.head(6)
# Out:
#                       KNN        RF        LR        DT       ELM       XGB  \
# Accuracy Score   0.998150  0.996890  0.973196  0.997806  0.985972  0.999348
# Precision Score  0.443425  0.310924  0.049890  0.390805  0.087740  0.773481
# Recall Score     0.838150  0.855491  0.919075  0.786127  0.872832  0.809249
# F1 Score         0.580000  0.456086  0.094643  0.522073  0.159451  0.790960
# AUC              0.918272  0.926298  0.946177  0.892128  0.929489  0.904443
#
#                       CNN
# Accuracy Score   0.985373
# Precision Score  0.083473
# Recall Score     0.861272
# F1 Score         0.152196
# AUC              0.923417

# %%
Metrics_smote.transpose().plot.bar(xlabel='classifiers',ylabel='Performance',
                             y=['Accuracy Score','Recall Score','AUC'],
                             figsize=(15,5),
                             title='Comparison of Accuracy,Recall,AUC for all classifiers on SMOTE balanced Data')
# Out:
# <AxesSubplot:title={'center':'Comparison of Accuracy,Recall,AUC for all classifiers on SMOTE balanced Data'}, xlabel='classifiers', ylabel='Performance'>

# %%
CNN_14_smote_metric=CNN_14_Layers(X_train,X_test,y_train,y_test)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_35 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_35 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_48 (Dropout)        (None, 29, 32)            0
#
#  conv1d_36 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_36 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_49 (Dropout)        (None, 28, 64)            0
#
#  flatten_13 (Flatten)        (None, 1792)              0
#
#  activation_9 (Activation)   (None, 1792)              0
#
#  dense_53 (Dense)            (None, 64)                114752
#
#  dropout_50 (Dropout)        (None, 64)                0
#
#  dense_54 (Dense)            (None, 100)               6500
#
#  dense_55 (Dense)            (None, 50)                5050
#
# ...

# %%
Models=['KNN','RF','LR','DT','ELM','XGB','CNN']

AUC_Metrics={}
for model in Models:
    AUC_Metrics[model]={'Imbalanced':Metrics[model]['AUC'],
              'UnderSampling':Metrics_rus[model]['AUC'],
             'OverSampling':Metrics_ros[model]['AUC'],
             'SMOTE':Metrics_smote[model]['AUC']
            }

# %%
AUC_result=pd.DataFrame(AUC_Metrics)

# %%
AUC_result.head(6)
# Out:
#                     KNN        RF        LR        DT       ELM       XGB  \
# Imbalanced     0.866337  0.790878  0.769319  0.838207  0.877060  0.870661
# UnderSampling  0.928161  0.923245  0.937277  0.887033  0.923585  0.938129
# OverSampling   0.891927  0.905898  0.922795  0.833865  0.910762  0.885719
# SMOTE          0.918272  0.926298  0.946177  0.892128  0.929489  0.904443
#
#                     CNN
# Imbalanced     0.502155
# UnderSampling  0.914464
# OverSampling   0.919371
# SMOTE          0.923417

# %%
AUC_result.transpose().plot.bar(xlabel='classifiers',ylabel='Performance',
                             y=['Imbalanced','UnderSampling','OverSampling','SMOTE'],
                             figsize=(15,5),
                             title='Comparison of ROC_AUC_Score for all classifiers on balanced and imbalanced Data')
# Out:
# <AxesSubplot:title={'center':'Comparison of ROC_AUC_Score for all classifiers on balanced and imbalanced Data'}, xlabel='classifiers', ylabel='Performance'>

# %%
Models=['KNN','RF','LR','DT','ELM','XGB','CNN']

F1_score_Metrics={}
for model in Models:
    F1_score_Metrics[model]={'Imbalanced':Metrics[model]['F1 Score'],
              'UnderSampling':Metrics_rus[model]['F1 Score'],
             'OverSampling':Metrics_ros[model]['F1 Score'],
             'SMOTE':Metrics_smote[model]['F1 Score']
            }

# %%
F1_score_result=pd.DataFrame(F1_score_Metrics)

# %%
F1_score_result.head()
# Out:
#                     KNN        RF        LR        DT       ELM       XGB  \
# Imbalanced     0.821256  0.697674  0.659631  0.725173  0.806452  0.834951
# UnderSampling  0.137585  0.220731  0.077245  0.023854  0.078189  0.097015
# OverSampling   0.723658  0.457627  0.144613  0.704545  0.203801  0.838407
# SMOTE          0.580000  0.456086  0.094643  0.522073  0.159451  0.790960
#
#                     CNN
# Imbalanced     0.008584
# UnderSampling  0.212766
# OverSampling   0.157581
# SMOTE          0.152196

# %%
F1_score_result.transpose().plot.bar(xlabel='classifiers',ylabel='F1_score',
                             y=['Imbalanced','UnderSampling','OverSampling','SMOTE'],
                             figsize=(15,5),
                             title='Comparison of F1_Score for all classifiers on balanced and imbalanced Data')
# Out:
# <AxesSubplot:title={'center':'Comparison of F1_Score for all classifiers on balanced and imbalanced Data'}, xlabel='classifiers', ylabel='F1_score'>

# %%
Models=['KNN','RF','LR','DT','ELM','XGB','CNN']

Accuracy_Metrics={}
for model in Models:
    Accuracy_Metrics[model]={'Imbalanced':Metrics[model]['Accuracy Score'],
              'UnderSampling':Metrics_rus[model]['Accuracy Score'],
             'OverSampling':Metrics_ros[model]['Accuracy Score'],
             'SMOTE':Metrics_smote[model]['Accuracy Score']
            }

# %%
Accuracy_result=pd.DataFrame(Accuracy_Metrics)

# %%
Accuracy_result.head()
# Out:
#                     KNN        RF        LR        DT       ELM       XGB  \
# Imbalanced     0.999478  0.999175  0.999091  0.999161  0.999408  0.999521
# UnderSampling  0.983320  0.990792  0.966949  0.889665  0.968420  0.974412
# OverSampling   0.999020  0.996842  0.983322  0.999084  0.989370  0.999514
# SMOTE          0.998150  0.996890  0.973196  0.997806  0.985972  0.999348
#
#                     CNN
# Imbalanced     0.998372
# UnderSampling  0.990546
# OverSampling   0.985077
# SMOTE          0.985373

# %%
Accuracy_result.transpose().plot.bar(xlabel='classifiers',ylabel='Accuracy_score',
                             y=['Imbalanced','UnderSampling','OverSampling','SMOTE'],
                             figsize=(15,5),
                             title='Comparison of Accuracy_Score for all classifiers on balanced and imbalanced Data')
# Out:
# <AxesSubplot:title={'center':'Comparison of Accuracy_Score for all classifiers on balanced and imbalanced Data'}, xlabel='classifiers', ylabel='Accuracy_score'>
